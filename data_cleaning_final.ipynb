# %%
import pandas as pd

# %%
df = pd.read_csv("🇬🇭 Ghana Tech Ecosystem Survey 2025_Submissions_2026-01-25.csv")  # replace with your CSV path
df.head(5)
# Out:
#   Submission ID Respondent ID         Submitted at  \
# 0       GxLMAx2        rXexOX  2025-07-31 11:43:50
# 1       VLVgQZl        JyyOVR  2025-07-31 12:56:04
# 2       2EL0eKL        L88bNJ  2025-07-31 13:20:49
# 3       b5LPOEe        ROO4pQ  2025-07-31 13:38:06
# 4       5BLRLPd        7QQZzR  2025-07-31 13:43:35
#
#   What region in Ghana do you currently live in? (Select ONE)  \
# 0                                            Central
# 1                                      Greater Accra
# 2                                            Western
# 3                                      Greater Accra
# 4                                      Greater Accra
#
#   Age Range: (Select ONE) Gender Identity: (Select ONE)  \
# 0                   18–28                          Male
# 1                   18–28                        Female
# 2                   18–28                          Male
# 3                   18–28                          Male
# ...

# %%
df.columns.unique().to_list()
# Out:
# ['Submission ID',
#  'Respondent ID',
#  'Submitted at',
#  'What region in Ghana do you currently live in? (Select ONE)',
#  'Age Range: (Select ONE)',
#  'Gender Identity: (Select ONE)',
#  'Highest Educational Qualification: (Select ONE)',
#  'How many years of experience do you have in the tech industry (including freelancing, internships, and full-time roles)? (Select ONE)',
#  'Are you currently employed in tech? (Select ONE)',
#  'Your current primary role/function within the tech ecosystem: (Select ONE)',
#  'What type of organization do you currently work with? (Select ONE)',
#  'Where is your primary organization based? (Select ONE) ',
#  'Which tech vertical(s) are you currently working in or primarily focused on? (Select all that apply)',
#  'Which tech vertical(s) are you currently working in or primarily focused on? (Select all that apply) (Fintech (Financial Technology: Payments, Lending, Insurtech, Wealth Management))',
# ...

# %%
df_new = df[['Submission ID',
              'Respondent ID',
              'Submitted at',
              'What region in Ghana do you currently live in? (Select ONE)',
              'Age Range: (Select ONE)',
              'Gender Identity: (Select ONE)',
              'Highest Educational Qualification: (Select ONE)',
              'How many years of experience do you have in the tech industry (including freelancing, internships, and full-time roles)? (Select ONE)',
              'Are you currently employed in tech? (Select ONE)',
              'Your current primary role/function within the tech ecosystem: (Select ONE)',
              'What type of organization do you currently work with? (Select ONE)',
              'Where is your primary organization based? (Select ONE)']]
df_new.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_new = df[['Submission ID',
#       2               'Respondent ID',
#       3               'Submitted at',
#       4               'What region in Ghana do you currently live in? (Select ONE)',
#       5               'Age Range: (Select ONE)',
#       6               'Gender Identity: (Select ONE)',
#       7               'Highest Educational Qualification: (Select ONE)',
#       8               'How many years of experience do you have in the tech industry (including freelancing, internships, and full-time roles)? (Select ONE)',
#       9               'Are you currently employed in tech? (Select ONE)',
#      10               'Your current primary role/function within the tech ecosystem: (Select ONE)',
# ...
